# %%
import pandas as pd
df = pd.read_csv("realtor-data.csv")

# %%
df.head()
# Out:
#      status     price  bed  bath  acre_lot  \
# 0  for_sale  105000.0  3.0   2.0      0.12
# 1  for_sale   80000.0  4.0   2.0      0.08
# 2  for_sale   67000.0  2.0   1.0      0.15
# 3  for_sale  145000.0  4.0   2.0      0.10
# 4  for_sale   65000.0  6.0   2.0      0.05
#
#                                         full_address  \
# 0  Sector Yahuecas Titulo # V84, Adjuntas, PR, 00601
# 1            Km 78 9 Carr # 135, Adjuntas, PR, 00601
# 2            556G 556-G 16 St, Juana Diaz, PR, 00795
# 3  R5 Comunidad El Paraso Calle De Oro R-5 Ponce,...
# 4                    14 Navarro, Mayaguez, PR, 00680
#
#                                           street        city        state  \
# 0                   Sector Yahuecas Titulo # V84    Adjuntas  Puerto Rico
# 1                             Km 78 9 Carr # 135    Adjuntas  Puerto Rico
# 2                               556G 556-G 16 St  Juana Diaz  Puerto Rico
# 3  R5 Comunidad El Paraso Calle De Oro R-5 Ponce       Ponce  Puerto Rico
# ...

# %%
df.describe(include='all').T
# Out:
#                  count  unique                                   top    freq  \
# status          923159       2                              for_sale  921528
# price         923088.0     NaN                                   NaN     NaN
# bed           791456.0     NaN                                   NaN     NaN
# bath          807967.0     NaN                                   NaN     NaN
# acre_lot      649536.0     NaN                                   NaN     NaN
# full_address    923159  112232  4 Glen Ellen Blvd, Millis, MA, 02054     213
# street          921021  110324                     4 Glen Ellen Blvd     213
# city            923085    2542                         New York City   48801
# state           923159      18                            New Jersey  233722
# zip_code      922954.0     NaN                                   NaN     NaN
# house_size    625316.0     NaN                                   NaN     NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 923159 entries, 0 to 923158
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   status        923159 non-null  object
#  1   price         923088 non-null  float64
#  2   bed           791456 non-null  float64
#  3   bath          807967 non-null  float64
#  4   acre_lot      649536 non-null  float64
#  5   full_address  923159 non-null  object
#  6   street        921021 non-null  object
#  7   city          923085 non-null  object
#  8   state         923159 non-null  object
#  9   zip_code      922954 non-null  float64
#  10  house_size    625316 non-null  float64
#  11  sold_date     456396 non-null  object
# dtypes: float64(6), object(6)
# memory usage: 84.5+ MB

# %%
df.isna().sum()
# Out:
# status               0
# price               71
# bed             131703
# bath            115192
# acre_lot        273623
# full_address         0
# street            2138
# city                74
# state                0
# zip_code           205
# house_size      297843
# sold_date       466763
# dtype: int64

# %%
df.nunique()
# Out:
# status               2
# price             7210
# bed                 43
# bath                39
# acre_lot          3282
# full_address    112232
# street          110324
# city              2542
# state               18
# zip_code          3191
# house_size        6426
# sold_date         9940
# dtype: int64
